# %%
import pytesseract
from PIL import Image

# %%
img_file = "OCR/Zzal.jpg"
no_noise = "temp/no_noise.jpg"

# %%
img = Image.open(no_noise)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=600x600>

# %%
ocr_result = pytesseract.image_to_string(img)

# %%
print (ocr_result)
# Out:
# a. oe
#
# ALBERT CAMUS
# —
#
# He said, “Io the maider of hate, I
# found there wes, within me, on invincible
# love. In the midet of tears, | found there
# was, withio we, on invincible smile. In the
# midst of chaos, I found there was, within me,
# eo ravincible calm 1 resdized, throwgh it oll,
# thet in the midst of winter, I found there
# was, within one, an invincible summer. And
# thet makes ee happy. For it says thet no
# matter how bard the world pushes ogainst
# ine, within me, thera's something stronger
# something better, pushing right back.”
#
# 19.
